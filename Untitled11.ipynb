# %%
import pandas as pd
import numpy as np
import matplotlib as mp

# %%
df = pd.read_csv(r'/Users/macuser/Documents/Briths AL INternship/BA_reviews.csv')
df
df.head()
# Out:
#    Unnamed: 0                                            reviews
# 0           0  My family flew from Washington to London on a ...
# 1           1  Easy check in a T5. Galleries south and North ...
# 2           2  Flight delayed by an hour, it happens, no bigg...
# 3           3  he staff are very rude and not trained properl...
# 4           4  Good domestic flight operated by BA Cityflyer....

# %%
unnamed_columns = [col for col in df.columns if 'Unnamed: 0' in col]
df = df.drop(columns=unnamed_columns)
df.reset_index(drop=True, inplace=True)

df
# Out:
#                                                 reviews
# 0     My family flew from Washington to London on a ...
# 1     Easy check in a T5. Galleries south and North ...
# 2     Flight delayed by an hour, it happens, no bigg...
# 3     he staff are very rude and not trained properl...
# 4     Good domestic flight operated by BA Cityflyer....
# ...                                                 ...
# 2207  Flew British Airways business class from Londo...
# 2208  Review |  Berlin to Philadelphia via London He...
# 2209  Completely unimpressed with British Airways. T...
# 2210  I flew to LHR T5 on British Airways with a con...
# 2211  Review |  I was looking forward to trying the ...
#
# [2212 rows x 1 columns]

# %%
pip install textblob
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from textblob import TextBlob

# %%
# Create a new column for sentiment polarity
df['sentiment_polarity'] = df['reviews'].apply(lambda text: TextBlob(text).sentiment.polarity)

# Classify sentiment labels
df['sentiment_label'] = df['sentiment_polarity'].apply(lambda polarity: "Positive" if polarity > 0 else ("Negative" if polarity < 0 else "Neutral"))

# Display the DataFrame with sentiment analysis results
print(df)
# Out:
#                                                 reviews  sentiment_polarity  \
# 0     My family flew from Washington to London on a ...            0.203409
# 1     Easy check in a T5. Galleries south and North ...            0.201581
# 2     Flight delayed by an hour, it happens, no bigg...            0.225000
# 3     he staff are very rude and not trained properl...           -0.291250
# 4     Good domestic flight operated by BA Cityflyer....            0.236111
# ...                                                 ...                 ...
# 2207  Flew British Airways business class from Londo...           -0.007576
# 2208  Review |  Berlin to Philadelphia via London He...           -0.008478
# 2209  Completely unimpressed with British Airways. T...            0.036458
# 2210  I flew to LHR T5 on British Airways with a con...            0.000000
# 2211  Review |  I was looking forward to trying the ...           -0.136178
#
#      sentiment_label
# 0           Positive
# ...

# %%
df
# Out:
#                                                 reviews  sentiment_polarity  \
# 0     My family flew from Washington to London on a ...            0.203409
# 1     Easy check in a T5. Galleries south and North ...            0.201581
# 2     Flight delayed by an hour, it happens, no bigg...            0.225000
# 3     he staff are very rude and not trained properl...           -0.291250
# 4     Good domestic flight operated by BA Cityflyer....            0.236111
# ...                                                 ...                 ...
# 2207  Flew British Airways business class from Londo...           -0.007576
# 2208  Review |  Berlin to Philadelphia via London He...           -0.008478
# 2209  Completely unimpressed with British Airways. T...            0.036458
# 2210  I flew to LHR T5 on British Airways with a con...            0.000000
# 2211  Review |  I was looking forward to trying the ...           -0.136178
#
#      sentiment_label
# 0           Positive
# ...

# %%
sentiment_counts = df['sentiment_label'].value_counts()
sentiment_counts
# Out:
# Positive    1467
# Negative     732
# Neutral       13
# Name: sentiment_label, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(15, 6))
plt.scatter(df.index, df['sentiment_polarity'], color='blue', alpha=0.5)
plt.title('Sentiment Polarity of Reviews')
plt.xlabel('Review Index')
plt.ylabel('Sentiment Polarity')
plt.grid(True)
plt.show()

# %%
labels = sentiment_counts.index
sizes = sentiment_counts.values
colors = ['green','red','yellow']
explode = (0.1,0,0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors, autopct='%1.1f%%', shadow=True, startangle=140)
plt.axis('equal')
plt.title('Sentiment Distribution')
plt.show()
